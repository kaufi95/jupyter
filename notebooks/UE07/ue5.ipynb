// %% [markdown]
// ## Reihenentwicklung der Exponentialfunktion (6 Punkte)
//
// Die Exponentialfunktion ez soll mit Hilfe einer Reihenentwicklung berechnet werden. Schreiben Sie eine Funktion in C, welches die ersten N Glieder der Reihenentwicklung aufsummiert.
//
// ![Screenshot 2023-05-05 at 00.22.20.png](attachment:8865f8a2-e22f-422c-a8f4-13990b388fca.png)
//
// *z* soll *reell* und *N* soll *ganzzahlig* sein.
//
// Hinweis: Die Terme der Reihe sind in einer Schleife aufzusummieren. Dabei soll die Fakultät
// in der Schleife selbst berechnet werden (keine Bibliotheksfunktion!).

// %%
double exponentialFunction(double z, int N) {

    // BEGIN SOLUTION
    
    double expValue = 1;
    double fac = 1;
    double sum = 1;

    for (int i = 1; i < N; i++) {
        expValue *= z;
        fac *= i;
        sum += expValue / fac;
    }

    // END SOLUTION
    
    return sum;
}

// %%
if ((std::round(exponentialFunction(3.0, 50) * 1000.0) / 1000.0) != 20.086) {
    throw std::logic_error("Rules not correct implemented\n");
}

// BEGIN HIDDEN TESTS

if ((std::round(exponentialFunction(1, 1) * 1000.0) / 1000.0) != 1) {
    throw std::logic_error("Rules not correct implemented\n");
}

if ((std::round(exponentialFunction(0, 50) * 1000.0) / 1000.0) != 1) {
    throw std::logic_error("Rules not correct implemented\n");
}

if ((std::round(exponentialFunction(5.345, 25) * 1000.0) / 1000.0) != 209.558) {
    throw std::logic_error("Rules not correct implemented\n");
}

// END HIDDEN TESTS

printf("All tests passed! :)");
// Out:
// All tests passed! :)

// %%
// place your tests here (students)
